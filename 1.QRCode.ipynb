# %% [markdown]
# # Clone Coding: Generate QRCode
# from Instagram

# %%
pip install pyqrcode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36223 sha256=6c819753e3054005649e427d19c4fe44dae22dbed54a40754a5054dcce4687aa
#   Stored in directory: /root/.cache/pip/wheels/34/2d/20/082874e49a32cdcc87ebaf99dd0099fb7774ef30f010dfb6f2
# Successfully built pyqrcode
# ...

# %%
pip install pypng
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import pyqrcode
import png

from pyqrcode import QRCode

s = "www.google.com"
url = pyqrcode.create(s)
url.svg('URL_google.svg', scale=8)
url.png('URL_google.png', scale=8)

# %% [markdown]
# # Test Applications

# %%
import pyqrcode
import png

from pyqrcode import QRCode

s = "https://byungle.netlify.app/"
url = pyqrcode.create(s)
url.svg('URL_Test.svg', scale=8)
url.png('URL_Test.png', scale=8)
